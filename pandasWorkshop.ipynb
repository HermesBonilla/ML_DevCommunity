# %% [markdown]
# # Welcome to our Pandas Workshop!
#
# ---
#
# We will first start using the [Pokemon with stats](https://www.kaggle.com/abcsds/pokemon) Kaggle dataset.
#
# ![Pikachu with Mask](https://compote.slate.com/images/18ba92e4-e39b-44a3-af3b-88f735703fa7.png?width=780&height=520&rect=1560x1040&offset=0x0)

# %% [markdown]
# ## The Fundamentals
#
# ---
#
# ### Understanding our DataFrames and locating values

# %%
import pandas as pd
import numpy as np

pokemon = pd.read_csv('/work/Pokemon.csv')

pokemon.head(5) # Display the first 5 values of the dataset
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# We can also visualize the data in print format (less fancy looking!)
print(pokemon.head(5))
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon.tail(5) #Display the last 5 values of the dataset
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
print(pokemon.columns) # List all columns in our dataframe
print(f"\n{pokemon['Name'][0:10]}")
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
#
# 0                    Bulbasaur
# 1                      Ivysaur
# 2                     Venusaur
# 3        VenusaurMega Venusaur
# 4                   Charmander
# 5                   Charmeleon
# 6                    Charizard
# 7    CharizardMega Charizard X
# 8    CharizardMega Charizard Y
# 9                     Squirtle
# Name: Name, dtype: object

# %%
print(pokemon[['Name', 'Type 1', 'Type 2', 'Generation']]) # We can even display several column values from the DataFrame!
# Out:
#                       Name   Type 1  Type 2  Generation
# 0                Bulbasaur    Grass  Poison           1
# 1                  Ivysaur    Grass  Poison           1
# 2                 Venusaur    Grass  Poison           1
# 3    VenusaurMega Venusaur    Grass  Poison           1
# 4               Charmander     Fire     NaN           1
# ..                     ...      ...     ...         ...
# 795                Diancie     Rock   Fairy           6
# 796    DiancieMega Diancie     Rock   Fairy           6
# 797    HoopaHoopa Confined  Psychic   Ghost           6
# 798     HoopaHoopa Unbound  Psychic    Dark           6
# 799              Volcanion     Fire   Water           6
#
# [800 rows x 4 columns]

# %%
# Read each row using iloc
pokemon.iloc[0:5]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Find a specific value (Row, Column)
print(pokemon.iloc[4,1]) # Returns "Charmander" name
# Out:
# Charmander

# %%
# Go through each rows and print the index and row

for index, row in pokemon.iterrows():
    print(index, row['Name'], f"HP: {row['HP']}") # Iterates through the rows to get Index, Name, HP, etc.
# Out:
# 0 Bulbasaur HP: 45
# 1 Ivysaur HP: 60
# 2 Venusaur HP: 80
# 3 VenusaurMega Venusaur HP: 80
# 4 Charmander HP: 39
# 5 Charmeleon HP: 58
# 6 Charizard HP: 78
# 7 CharizardMega Charizard X HP: 78
# 8 CharizardMega Charizard Y HP: 78
# 9 Squirtle HP: 44
# 10 Wartortle HP: 59
# 11 Blastoise HP: 79
# 12 BlastoiseMega Blastoise HP: 79
# 13 Caterpie HP: 45
# 14 Metapod HP: 50
# 15 Butterfree HP: 60
# 16 Weedle HP: 40
# 17 Kakuna HP: 45
# 18 Beedrill HP: 65
# 19 BeedrillMega Beedrill HP: 65
# 20 Pidgey HP: 40
# 21 Pidgeotto HP: 63
# 22 Pidgeot HP: 83
# 23 PidgeotMega Pidgeot HP: 83
# 24 Rattata HP: 30
# 25 Raticate HP: 55
# 26 Spearow HP: 40
# 27 Fearow HP: 65
# 28 Ekans HP: 35
# 29 Arbok HP: 60
# 30 Pikachu HP: 35
# 31 Raichu HP: 60
# 32 Sandshrew HP: 50
# 33 Sandslash HP: 75
# 34 Nidoran♀ HP: 55
# 35 Nidorina HP: 70
# 36 Nidoqueen HP: 90
# 37 Nidoran♂ HP: 46
# 38 Nidorino HP: 61
# 39 Nidoking HP: 81
# 40 Clefairy HP: 70
# 41 Clefable HP: 95
# 42 Vulpix HP: 38
# 43 Ninetales HP: 73
# 44 Jigglypuff HP: 115
# 45 Wigglytuff HP: 140
# 46 Zubat HP: 40
# 47 Golbat HP: 75
# 48 Oddish HP: 45
# 49 Gloom HP: 60
# 50 Vileplume HP: 75
# 51 Paras HP: 35
# 52 Parasect HP: 60
# 53 Venonat HP: 60
# 54 Venomoth HP: 70
# 55 Diglett HP: 10
# 56 Dugtrio HP: 35
# 57 Meowth HP: 40
# 58 Persian HP: 65
# 59 Psyduck HP: 50
# 60 Golduck HP: 80
# 61 Mankey HP: 40
# 62 Primeape HP: 65
# 63 Growlithe HP: 55
# 64 Arcanine HP: 90
# 65 Poliwag HP: 40
# 66 Poliwhirl HP: 65
# 67 Poliwrath HP: 90
# 68 Abra HP: 25
# 69 Kadabra HP: 40
# 70 Alakazam HP: 55
# 71 AlakazamMega Alakazam HP: 55
# 72 Machop HP: 70
# 73 Machoke HP: 80
# 74 Machamp HP: 90
# 75 Bellsprout HP: 50
# 76 Weepinbell HP: 65
# 77 Victreebel HP: 80
# 78 Tentacool HP: 40
# 79 Tentacruel HP: 80
# 80 Geodude HP: 40
# 81 Graveler HP: 55
# 82 Golem HP: 80
# 83 Ponyta HP: 50
# 84 Rapidash HP: 65
# 85 Slowpoke HP: 90
# 86 Slowbro HP: 95
# 87 SlowbroMega Slowbro HP: 95
# 88 Magnemite HP: 25
# 89 Magneton HP: 50
# 90 Farfetch'd HP: 52
# 91 Doduo HP: 35
# 92 Dodrio HP: 60
# 93 Seel HP: 65
# 94 Dewgong HP: 90
# 95 Grimer HP: 80
# 96 Muk HP: 105
# 97 Shellder HP: 30
# 98 Cloyster HP: 50
# 99 Gastly HP: 30
# 100 Haunter HP: 45
# 101 Gengar HP: 60
# 102 GengarMega Gengar HP: 60
# 103 Onix HP: 35
# 104 Drowzee HP: 60
# 105 Hypno HP: 85
# 106 Krabby HP: 30
# 107 Kingler HP: 55
# 108 Voltorb HP: 40
# 109 Electrode HP: 60
# 110 Exeggcute HP: 60
# 111 Exeggutor HP: 95
# 112 Cubone HP: 50
# 113 Marowak HP: 60
# 114 Hitmonlee HP: 50
# 115 Hitmonchan HP: 50
# 116 Lickitung HP: 90
# 117 Koffing HP: 40
# 118 Weezing HP: 65
# 119 Rhyhorn HP: 80
# 120 Rhydon HP: 105
# 121 Chansey HP: 250
# 122 Tangela HP: 65
# 123 Kangaskhan HP: 105
# 124 KangaskhanMega Kangaskhan HP: 105
# 125 Horsea HP: 30
# 126 Seadra HP: 55
# 127 Goldeen HP: 45
# 128 Seaking HP: 80
# 129 Staryu HP: 30
# 130 Starmie HP: 60
# 131 Mr. Mime HP: 40
# 132 Scyther HP: 70
# 133 Jynx HP: 65
# 134 Electabuzz HP: 65
# 135 Magmar HP: 65
# 136 Pinsir HP: 65
# 137 PinsirMega Pinsir HP: 65
# 138 Tauros HP: 75
# 139 Magikarp HP: 20
# 140 Gyarados HP: 95
# 141 GyaradosMega Gyarados HP: 95
# 142 Lapras HP: 130
# 143 Ditto HP: 48
# 144 Eevee HP: 55
# 145 Vaporeon HP: 130
# 146 Jolteon HP: 65
# 147 Flareon HP: 65
# 148 Porygon HP: 65
# 149 Omanyte HP: 35
# 150 Omastar HP: 70
# 151 Kabuto HP: 30
# 152 Kabutops HP: 60
# 153 Aerodactyl HP: 80
# 154 AerodactylMega Aerodactyl HP: 80
# 155 Snorlax HP: 160
# 156 Articuno HP: 90
# 157 Zapdos HP: 90
# 158 Moltres HP: 90
# 159 Dratini HP: 41
# 160 Dragonair HP: 61
# 161 Dragonite HP: 91
# 162 Mewtwo HP: 106
# 163 MewtwoMega Mewtwo X HP: 106
# 164 MewtwoMega Mewtwo Y HP: 106
# 165 Mew HP: 100
# 166 Chikorita HP: 45
# 167 Bayleef HP: 60
# 168 Meganium HP: 80
# 169 Cyndaquil HP: 39
# 170 Quilava HP: 58
# 171 Typhlosion HP: 78
# 172 Totodile HP: 50
# 173 Croconaw HP: 65
# 174 Feraligatr HP: 85
# 175 Sentret HP: 35
# 176 Furret HP: 85
# 177 Hoothoot HP: 60
# 178 Noctowl HP: 100
# 179 Ledyba HP: 40
# 180 Ledian HP: 55
# 181 Spinarak HP: 40
# 182 Ariados HP: 70
# 183 Crobat HP: 85
# 184 Chinchou HP: 75
# 185 Lanturn HP: 125
# 186 Pichu HP: 20
# 187 Cleffa HP: 50
# 188 Igglybuff HP: 90
# 189 Togepi HP: 35
# 190 Togetic HP: 55
# 191 Natu HP: 40
# 192 Xatu HP: 65
# 193 Mareep HP: 55
# 194 Flaaffy HP: 70
# 195 Ampharos HP: 90
# 196 AmpharosMega Ampharos HP: 90
# 197 Bellossom HP: 75
# 198 Marill HP: 70
# 199 Azumarill HP: 100
# 200 Sudowoodo HP: 70
# 201 Politoed HP: 90
# 202 Hoppip HP: 35
# 203 Skiploom HP: 55
# 204 Jumpluff HP: 75
# 205 Aipom HP: 55
# 206 Sunkern HP: 30
# 207 Sunflora HP: 75
# 208 Yanma HP: 65
# 209 Wooper HP: 55
# 210 Quagsire HP: 95
# 211 Espeon HP: 65
# 212 Umbreon HP: 95
# 213 Murkrow HP: 60
# 214 Slowking HP: 95
# 215 Misdreavus HP: 60
# 216 Unown HP: 48
# 217 Wobbuffet HP: 190
# 218 Girafarig HP: 70
# 219 Pineco HP: 50
# 220 Forretress HP: 75
# 221 Dunsparce HP: 100
# 222 Gligar HP: 65
# 223 Steelix HP: 75
# 224 SteelixMega Steelix HP: 75
# 225 Snubbull HP: 60
# 226 Granbull HP: 90
# 227 Qwilfish HP: 65
# 228 Scizor HP: 70
# 229 ScizorMega Scizor HP: 70
# 230 Shuckle HP: 20
# 231 Heracross HP: 80
# 232 HeracrossMega Heracross HP: 80
# 233 Sneasel HP: 55
# 234 Teddiursa HP: 60
# 235 Ursaring HP: 90
# 236 Slugma HP: 40
# 237 Magcargo HP: 50
# 238 Swinub HP: 50
# 239 Piloswine HP: 100
# 240 Corsola HP: 55
# 241 Remoraid HP: 35
# 242 Octillery HP: 75
# 243 Delibird HP: 45
# 244 Mantine HP: 65
# 245 Skarmory HP: 65
# 246 Houndour HP: 45
# 247 Houndoom HP: 75
# 248 HoundoomMega Houndoom HP: 75
# 249 Kingdra HP: 75
# 250 Phanpy HP: 90
# 251 Donphan HP: 90
# 252 Porygon2 HP: 85
# 253 Stantler HP: 73
# 254 Smeargle HP: 55
# 255 Tyrogue HP: 35
# 256 Hitmontop HP: 50
# 257 Smoochum HP: 45
# 258 Elekid HP: 45
# 259 Magby HP: 45
# 260 Miltank HP: 95
# 261 Blissey HP: 255
# 262 Raikou HP: 90
# 263 Entei HP: 115
# 264 Suicune HP: 100
# 265 Larvitar HP: 50
# 266 Pupitar HP: 70
# 267 Tyranitar HP: 100
# 268 TyranitarMega Tyranitar HP: 100
# 269 Lugia HP: 106
# 270 Ho-oh HP: 106
# 271 Celebi HP: 100
# 272 Treecko HP: 40
# 273 Grovyle HP: 50
# 274 Sceptile HP: 70
# 275 SceptileMega Sceptile HP: 70
# 276 Torchic HP: 45
# 277 Combusken HP: 60
# 278 Blaziken HP: 80
# 279 BlazikenMega Blaziken HP: 80
# 280 Mudkip HP: 50
# 281 Marshtomp HP: 70
# 282 Swampert HP: 100
# 283 SwampertMega Swampert HP: 100
# 284 Poochyena HP: 35
# 285 Mightyena HP: 70
# 286 Zigzagoon HP: 38
# 287 Linoone HP: 78
# 288 Wurmple HP: 45
# 289 Silcoon HP: 50
# 290 Beautifly HP: 60
# 291 Cascoon HP: 50
# 292 Dustox HP: 60
# 293 Lotad HP: 40
# 294 Lombre HP: 60
# 295 Ludicolo HP: 80
# 296 Seedot HP: 40
# 297 Nuzleaf HP: 70
# 298 Shiftry HP: 90
# 299 Taillow HP: 40
# 300 Swellow HP: 60
# 301 Wingull HP: 40
# 302 Pelipper HP: 60
# 303 Ralts HP: 28
# 304 Kirlia HP: 38
# 305 Gardevoir HP: 68
# 306 GardevoirMega Gardevoir HP: 68
# 307 Surskit HP: 40
# 308 Masquerain HP: 70
# 309 Shroomish HP: 60
# 310 Breloom HP: 60
# 311 Slakoth HP: 60
# 312 Vigoroth HP: 80
# 313 Slaking HP: 150
# 314 Nincada HP: 31
# 315 Ninjask HP: 61
# 316 Shedinja HP: 1
# 317 Whismur HP: 64
# 318 Loudred HP: 84
# 319 Exploud HP: 104
# 320 Makuhita HP: 72
# 321 Hariyama HP: 144
# 322 Azurill HP: 50
# 323 Nosepass HP: 30
# 324 Skitty HP: 50
# 325 Delcatty HP: 70
# 326 Sableye HP: 50
# 327 SableyeMega Sableye HP: 50
# 328 Mawile HP: 50
# 329 MawileMega Mawile HP: 50
# 330 Aron HP: 50
# 331 Lairon HP: 60
# 332 Aggron HP: 70
# 333 AggronMega Aggron HP: 70
# 334 Meditite HP: 30
# 335 Medicham HP: 60
# 336 MedichamMega Medicham HP: 60
# 337 Electrike HP: 40
# 338 Manectric HP: 70
# 339 ManectricMega Manectric HP: 70
# 340 Plusle HP: 60
# 341 Minun HP: 60
# 342 Volbeat HP: 65
# 343 Illumise HP: 65
# 344 Roselia HP: 50
# 345 Gulpin HP: 70
# 346 Swalot HP: 100
# 347 Carvanha HP: 45
# 348 Sharpedo HP: 70
# 349 SharpedoMega Sharpedo HP: 70
# 350 Wailmer HP: 130
# 351 Wailord HP: 170
# 352 Numel HP: 60
# 353 Camerupt HP: 70
# 354 CameruptMega Camerupt HP: 70
# 355 Torkoal HP: 70
# 356 Spoink HP: 60
# 357 Grumpig HP: 80
# 358 Spinda HP: 60
# 359 Trapinch HP: 45
# 360 Vibrava HP: 50
# 361 Flygon HP: 80
# 362 Cacnea HP: 50
# 363 Cacturne HP: 70
# 364 Swablu HP: 45
# 365 Altaria HP: 75
# 366 AltariaMega Altaria HP: 75
# 367 Zangoose HP: 73
# 368 Seviper HP: 73
# 369 Lunatone HP: 70
# 370 Solrock HP: 70
# 371 Barboach HP: 50
# 372 Whiscash HP: 110
# 373 Corphish HP: 43
# 374 Crawdaunt HP: 63
# 375 Baltoy HP: 40
# 376 Claydol HP: 60
# 377 Lileep HP: 66
# 378 Cradily HP: 86
# 379 Anorith HP: 45
# 380 Armaldo HP: 75
# 381 Feebas HP: 20
# 382 Milotic HP: 95
# 383 Castform HP: 70
# 384 Kecleon HP: 60
# 385 Shuppet HP: 44
# 386 Banette HP: 64
# 387 BanetteMega Banette HP: 64
# 388 Duskull HP: 20
# 389 Dusclops HP: 40
# 390 Tropius HP: 99
# 391 Chimecho HP: 65
# 392 Absol HP: 65
# 393 AbsolMega Absol HP: 65
# 394 Wynaut HP: 95
# 395 Snorunt HP: 50
# 396 Glalie HP: 80
# 397 GlalieMega Glalie HP: 80
# 398 Spheal HP: 70
# 399 Sealeo HP: 90
# 400 Walrein HP: 110
# 401 Clamperl HP: 35
# 402 Huntail HP: 55
# 403 Gorebyss HP: 55
# 404 Relicanth HP: 100
# 405 Luvdisc HP: 43
# 406 Bagon HP: 45
# 407 Shelgon HP: 65
# 408 Salamence HP: 95
# 409 SalamenceMega Salamence HP: 95
# 410 Beldum HP: 40
# 411 Metang HP: 60
# 412 Metagross HP: 80
# 413 MetagrossMega Metagross HP: 80
# 414 Regirock HP: 80
# 415 Regice HP: 80
# 416 Registeel HP: 80
# 417 Latias HP: 80
# 418 LatiasMega Latias HP: 80
# 419 Latios HP: 80
# 420 LatiosMega Latios HP: 80
# 421 Kyogre HP: 100
# 422 KyogrePrimal Kyogre HP: 100
# 423 Groudon HP: 100
# 424 GroudonPrimal Groudon HP: 100
# 425 Rayquaza HP: 105
# 426 RayquazaMega Rayquaza HP: 105
# 427 Jirachi HP: 100
# 428 DeoxysNormal Forme HP: 50
# 429 DeoxysAttack Forme HP: 50
# 430 DeoxysDefense Forme HP: 50
# 431 DeoxysSpeed Forme HP: 50
# 432 Turtwig HP: 55
# 433 Grotle HP: 75
# 434 Torterra HP: 95
# 435 Chimchar HP: 44
# 436 Monferno HP: 64
# 437 Infernape HP: 76
# 438 Piplup HP: 53
# 439 Prinplup HP: 64
# 440 Empoleon HP: 84
# 441 Starly HP: 40
# 442 Staravia HP: 55
# 443 Staraptor HP: 85
# 444 Bidoof HP: 59
# 445 Bibarel HP: 79
# 446 Kricketot HP: 37
# 447 Kricketune HP: 77
# 448 Shinx HP: 45
# 449 Luxio HP: 60
# 450 Luxray HP: 80
# 451 Budew HP: 40
# 452 Roserade HP: 60
# 453 Cranidos HP: 67
# 454 Rampardos HP: 97
# 455 Shieldon HP: 30
# 456 Bastiodon HP: 60
# 457 Burmy HP: 40
# 458 WormadamPlant Cloak HP: 60
# 459 WormadamSandy Cloak HP: 60
# 460 WormadamTrash Cloak HP: 60
# 461 Mothim HP: 70
# 462 Combee HP: 30
# 463 Vespiquen HP: 70
# 464 Pachirisu HP: 60
# 465 Buizel HP: 55
# 466 Floatzel HP: 85
# 467 Cherubi HP: 45
# 468 Cherrim HP: 70
# 469 Shellos HP: 76
# 470 Gastrodon HP: 111
# 471 Ambipom HP: 75
# 472 Drifloon HP: 90
# 473 Drifblim HP: 150
# 474 Buneary HP: 55
# 475 Lopunny HP: 65
# 476 LopunnyMega Lopunny HP: 65
# 477 Mismagius HP: 60
# 478 Honchkrow HP: 100
# 479 Glameow HP: 49
# 480 Purugly HP: 71
# 481 Chingling HP: 45
# 482 Stunky HP: 63
# 483 Skuntank HP: 103
# 484 Bronzor HP: 57
# 485 Bronzong HP: 67
# 486 Bonsly HP: 50
# 487 Mime Jr. HP: 20
# 488 Happiny HP: 100
# 489 Chatot HP: 76
# 490 Spiritomb HP: 50
# 491 Gible HP: 58
# 492 Gabite HP: 68
# 493 Garchomp HP: 108
# 494 GarchompMega Garchomp HP: 108
# 495 Munchlax HP: 135
# 496 Riolu HP: 40
# 497 Lucario HP: 70
# 498 LucarioMega Lucario HP: 70
# 499 Hippopotas HP: 68
# 500 Hippowdon HP: 108
# 501 Skorupi HP: 40
# 502 Drapion HP: 70
# 503 Croagunk HP: 48
# 504 Toxicroak HP: 83
# 505 Carnivine HP: 74
# 506 Finneon HP: 49
# 507 Lumineon HP: 69
# 508 Mantyke HP: 45
# 509 Snover HP: 60
# 510 Abomasnow HP: 90
# 511 AbomasnowMega Abomasnow HP: 90
# 512 Weavile HP: 70
# 513 Magnezone HP: 70
# 514 Lickilicky HP: 110
# 515 Rhyperior HP: 115
# 516 Tangrowth HP: 100
# 517 Electivire HP: 75
# 518 Magmortar HP: 75
# 519 Togekiss HP: 85
# 520 Yanmega HP: 86
# 521 Leafeon HP: 65
# 522 Glaceon HP: 65
# 523 Gliscor HP: 75
# 524 Mamoswine HP: 110
# 525 Porygon-Z HP: 85
# 526 Gallade HP: 68
# 527 GalladeMega Gallade HP: 68
# 528 Probopass HP: 60
# 529 Dusknoir HP: 45
# 530 Froslass HP: 70
# 531 Rotom HP: 50
# 532 RotomHeat Rotom HP: 50
# 533 RotomWash Rotom HP: 50
# 534 RotomFrost Rotom HP: 50
# 535 RotomFan Rotom HP: 50
# 536 RotomMow Rotom HP: 50
# 537 Uxie HP: 75
# 538 Mesprit HP: 80
# 539 Azelf HP: 75
# 540 Dialga HP: 100
# 541 Palkia HP: 90
# 542 Heatran HP: 91
# 543 Regigigas HP: 110
# 544 GiratinaAltered Forme HP: 150
# 545 GiratinaOrigin Forme HP: 150
# 546 Cresselia HP: 120
# 547 Phione HP: 80
# 548 Manaphy HP: 100
# 549 Darkrai HP: 70
# 550 ShayminLand Forme HP: 100
# 551 ShayminSky Forme HP: 100
# 552 Arceus HP: 120
# 553 Victini HP: 100
# 554 Snivy HP: 45
# 555 Servine HP: 60
# 556 Serperior HP: 75
# 557 Tepig HP: 65
# 558 Pignite HP: 90
# 559 Emboar HP: 110
# 560 Oshawott HP: 55
# 561 Dewott HP: 75
# 562 Samurott HP: 95
# 563 Patrat HP: 45
# 564 Watchog HP: 60
# 565 Lillipup HP: 45
# 566 Herdier HP: 65
# 567 Stoutland HP: 85
# 568 Purrloin HP: 41
# 569 Liepard HP: 64
# 570 Pansage HP: 50
# 571 Simisage HP: 75
# 572 Pansear HP: 50
# 573 Simisear HP: 75
# 574 Panpour HP: 50
# 575 Simipour HP: 75
# 576 Munna HP: 76
# 577 Musharna HP: 116
# 578 Pidove HP: 50
# 579 Tranquill HP: 62
# 580 Unfezant HP: 80
# 581 Blitzle HP: 45
# 582 Zebstrika HP: 75
# 583 Roggenrola HP: 55
# 584 Boldore HP: 70
# 585 Gigalith HP: 85
# 586 Woobat HP: 55
# 587 Swoobat HP: 67
# 588 Drilbur HP: 60
# 589 Excadrill HP: 110
# 590 Audino HP: 103
# 591 AudinoMega Audino HP: 103
# 592 Timburr HP: 75
# 593 Gurdurr HP: 85
# 594 Conkeldurr HP: 105
# 595 Tympole HP: 50
# 596 Palpitoad HP: 75
# 597 Seismitoad HP: 105
# 598 Throh HP: 120
# 599 Sawk HP: 75
# 600 Sewaddle HP: 45
# 601 Swadloon HP: 55
# 602 Leavanny HP: 75
# 603 Venipede HP: 30
# 604 Whirlipede HP: 40
# 605 Scolipede HP: 60
# 606 Cottonee HP: 40
# 607 Whimsicott HP: 60
# 608 Petilil HP: 45
# 609 Lilligant HP: 70
# 610 Basculin HP: 70
# 611 Sandile HP: 50
# 612 Krokorok HP: 60
# 613 Krookodile HP: 95
# 614 Darumaka HP: 70
# 615 DarmanitanStandard Mode HP: 105
# 616 DarmanitanZen Mode HP: 105
# 617 Maractus HP: 75
# 618 Dwebble HP: 50
# 619 Crustle HP: 70
# 620 Scraggy HP: 50
# 621 Scrafty HP: 65
# 622 Sigilyph HP: 72
# 623 Yamask HP: 38
# 624 Cofagrigus HP: 58
# 625 Tirtouga HP: 54
# 626 Carracosta HP: 74
# 627 Archen HP: 55
# 628 Archeops HP: 75
# 629 Trubbish HP: 50
# 630 Garbodor HP: 80
# 631 Zorua HP: 40
# 632 Zoroark HP: 60
# 633 Minccino HP: 55
# 634 Cinccino HP: 75
# 635 Gothita HP: 45
# 636 Gothorita HP: 60
# 637 Gothitelle HP: 70
# 638 Solosis HP: 45
# 639 Duosion HP: 65
# 640 Reuniclus HP: 110
# 641 Ducklett HP: 62
# 642 Swanna HP: 75
# 643 Vanillite HP: 36
# 644 Vanillish HP: 51
# 645 Vanilluxe HP: 71
# 646 Deerling HP: 60
# 647 Sawsbuck HP: 80
# 648 Emolga HP: 55
# 649 Karrablast HP: 50
# 650 Escavalier HP: 70
# 651 Foongus HP: 69
# 652 Amoonguss HP: 114
# 653 Frillish HP: 55
# 654 Jellicent HP: 100
# 655 Alomomola HP: 165
# 656 Joltik HP: 50
# 657 Galvantula HP: 70
# 658 Ferroseed HP: 44
# 659 Ferrothorn HP: 74
# 660 Klink HP: 40
# 661 Klang HP: 60
# 662 Klinklang HP: 60
# 663 Tynamo HP: 35
# 664 Eelektrik HP: 65
# 665 Eelektross HP: 85
# 666 Elgyem HP: 55
# 667 Beheeyem HP: 75
# 668 Litwick HP: 50
# 669 Lampent HP: 60
# 670 Chandelure HP: 60
# 671 Axew HP: 46
# 672 Fraxure HP: 66
# 673 Haxorus HP: 76
# 674 Cubchoo HP: 55
# 675 Beartic HP: 95
# 676 Cryogonal HP: 70
# 677 Shelmet HP: 50
# 678 Accelgor HP: 80
# 679 Stunfisk HP: 109
# 680 Mienfoo HP: 45
# 681 Mienshao HP: 65
# 682 Druddigon HP: 77
# 683 Golett HP: 59
# 684 Golurk HP: 89
# 685 Pawniard HP: 45
# 686 Bisharp HP: 65
# 687 Bouffalant HP: 95
# 688 Rufflet HP: 70
# 689 Braviary HP: 100
# 690 Vullaby HP: 70
# 691 Mandibuzz HP: 110
# 692 Heatmor HP: 85
# 693 Durant HP: 58
# 694 Deino HP: 52
# 695 Zweilous HP: 72
# 696 Hydreigon HP: 92
# 697 Larvesta HP: 55
# 698 Volcarona HP: 85
# 699 Cobalion HP: 91
# 700 Terrakion HP: 91
# 701 Virizion HP: 91
# 702 TornadusIncarnate Forme HP: 79
# 703 TornadusTherian Forme HP: 79
# 704 ThundurusIncarnate Forme HP: 79
# 705 ThundurusTherian Forme HP: 79
# 706 Reshiram HP: 100
# 707 Zekrom HP: 100
# 708 LandorusIncarnate Forme HP: 89
# 709 LandorusTherian Forme HP: 89
# 710 Kyurem HP: 125
# 711 KyuremBlack Kyurem HP: 125
# 712 KyuremWhite Kyurem HP: 125
# 713 KeldeoOrdinary Forme HP: 91
# 714 KeldeoResolute Forme HP: 91
# 715 MeloettaAria Forme HP: 100
# 716 MeloettaPirouette Forme HP: 100
# 717 Genesect HP: 71
# 718 Chespin HP: 56
# 719 Quilladin HP: 61
# 720 Chesnaught HP: 88
# 721 Fennekin HP: 40
# 722 Braixen HP: 59
# 723 Delphox HP: 75
# 724 Froakie HP: 41
# 725 Frogadier HP: 54
# 726 Greninja HP: 72
# 727 Bunnelby HP: 38
# 728 Diggersby HP: 85
# 729 Fletchling HP: 45
# 730 Fletchinder HP: 62
# 731 Talonflame HP: 78
# 732 Scatterbug HP: 38
# 733 Spewpa HP: 45
# 734 Vivillon HP: 80
# 735 Litleo HP: 62
# 736 Pyroar HP: 86
# 737 Flabébé HP: 44
# 738 Floette HP: 54
# 739 Florges HP: 78
# 740 Skiddo HP: 66
# 741 Gogoat HP: 123
# 742 Pancham HP: 67
# 743 Pangoro HP: 95
# 744 Furfrou HP: 75
# 745 Espurr HP: 62
# 746 MeowsticMale HP: 74
# 747 MeowsticFemale HP: 74
# 748 Honedge HP: 45
# 749 Doublade HP: 59
# 750 AegislashBlade Forme HP: 60
# 751 AegislashShield Forme HP: 60
# 752 Spritzee HP: 78
# 753 Aromatisse HP: 101
# 754 Swirlix HP: 62
# 755 Slurpuff HP: 82
# 756 Inkay HP: 53
# 757 Malamar HP: 86
# 758 Binacle HP: 42
# 759 Barbaracle HP: 72
# 760 Skrelp HP: 50
# 761 Dragalge HP: 65
# 762 Clauncher HP: 50
# 763 Clawitzer HP: 71
# 764 Helioptile HP: 44
# 765 Heliolisk HP: 62
# 766 Tyrunt HP: 58
# 767 Tyrantrum HP: 82
# 768 Amaura HP: 77
# 769 Aurorus HP: 123
# 770 Sylveon HP: 95
# 771 Hawlucha HP: 78
# 772 Dedenne HP: 67
# 773 Carbink HP: 50
# 774 Goomy HP: 45
# 775 Sliggoo HP: 68
# 776 Goodra HP: 90
# 777 Klefki HP: 57
# 778 Phantump HP: 43
# 779 Trevenant HP: 85
# 780 PumpkabooAverage Size HP: 49
# 781 PumpkabooSmall Size HP: 44
# 782 PumpkabooLarge Size HP: 54
# 783 PumpkabooSuper Size HP: 59
# 784 GourgeistAverage Size HP: 65
# 785 GourgeistSmall Size HP: 55
# 786 GourgeistLarge Size HP: 75
# 787 GourgeistSuper Size HP: 85
# 788 Bergmite HP: 55
# 789 Avalugg HP: 95
# 790 Noibat HP: 40
# 791 Noivern HP: 85
# 792 Xerneas HP: 126
# 793 Yveltal HP: 126
# 794 Zygarde50% Forme HP: 108
# 795 Diancie HP: 50
# 796 DiancieMega Diancie HP: 50
# 797 HoopaHoopa Confined HP: 80
# 798 HoopaHoopa Unbound HP: 80
# 799 Volcanion HP: 80

# %% [markdown]
# #### Note:
# **iloc** stands for integer location
# ```python
# pokemon.iloc[]
# ```
#
# **loc** stands for location (general labels)
# ```python
# pokemon.loc[]
# ```

# %%
# loc function can have multiple conditions so that you may include specific values
pokemon.loc[(pokemon['Legendary'] == True) & ((pokemon['Type 1'] == 'Flying') | (pokemon['Type 2'] == 'Flying'))]
# Out:
#        #                      Name    Type 1  Type 2  Total   HP  Attack  \
# 156  144                  Articuno       Ice  Flying    580   90      85
# 157  145                    Zapdos  Electric  Flying    580   90      90
# 158  146                   Moltres      Fire  Flying    580   90     100
# 269  249                     Lugia   Psychic  Flying    680  106      90
# 270  250                     Ho-oh      Fire  Flying    680  106     130
# 425  384                  Rayquaza    Dragon  Flying    680  105     150
# 426  384     RayquazaMega Rayquaza    Dragon  Flying    780  105     180
# 551  492          ShayminSky Forme     Grass  Flying    600  100     103
# 702  641   TornadusIncarnate Forme    Flying     NaN    580   79     115
# 703  641     TornadusTherian Forme    Flying     NaN    580   79     100
# 704  642  ThundurusIncarnate Forme  Electric  Flying    580   79     115
# 705  642    ThundurusTherian Forme  Electric  Flying    580   79     105
# 708  645   LandorusIncarnate Forme    Ground  Flying    600   89     125
# 709  645     LandorusTherian Forme    Ground  Flying    600   89     145
# 793  717                   Yveltal      Dark  Flying    680  126     131
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# 158       90      125       85     90           1       True
# 269      130       90      154    110           2       True
# 270       90      110      154     90           2       True
# 425       90      150       90     95           3       True
# 426      100      180      100    115           3       True
# 551       75      120       75    127           4       True
# 702       70      125       80    111           5       True
# 703       80      110       90    121           5       True
# 704       70      125       80    111           5       True
# 705       70      145       80    101           5       True
# 708       90      115       80    101           5       True
# 709       90      105       80     91           5       True
# 793       95      131       98     99           6       True

# %% [markdown]
# ## Manipulating Our Dataframe
#
# ---
#
# ### Adding, dropping, rearranging, and combining columns
#
#
# Let's mess around with the structure of our dataframes
#
# Pandas documentation:
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.copy.html

# %%
# code here

pokemod = pokemon.copy()

# %%
pokemod2 = pokemod.drop(columns=['Sp. Atk','Sp. Def','Generation'])
pokemod2.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  Speed  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49     45
# 1  2                Ivysaur  Grass  Poison    405  60      62       63     60
# 2  3               Venusaur  Grass  Poison    525  80      82       83     80
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123     80
# 4  4             Charmander   Fire     NaN    309  39      52       43     65
#
#    Legendary
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
pokemod2.drop(columns=['Legendary'], inplace=True)
pokemod2.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  Speed
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49     45
# 1  2                Ivysaur  Grass  Poison    405  60      62       63     60
# 2  3               Venusaur  Grass  Poison    525  80      82       83     80
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123     80
# 4  4             Charmander   Fire     NaN    309  39      52       43     65

# %%
pokemod2['Legendary'] = np.nan
pokemod2.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  Speed  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49     45
# 1  2                Ivysaur  Grass  Poison    405  60      62       63     60
# 2  3               Venusaur  Grass  Poison    525  80      82       83     80
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123     80
# 4  4             Charmander   Fire     NaN    309  39      52       43     65
#
#    Legendary
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
pokemod2['isPokemon'] = True
pokemod2.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  Speed  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49     45
# 1  2                Ivysaur  Grass  Poison    405  60      62       63     60
# 2  3               Venusaur  Grass  Poison    525  80      82       83     80
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123     80
# 4  4             Charmander   Fire     NaN    309  39      52       43     65
#
#    Legendary  isPokemon
# 0        NaN       True
# 1        NaN       True
# 2        NaN       True
# 3        NaN       True
# 4        NaN       True

# %%
pokemod2['Offense'] = pokemod2['Attack'] + pokemod2['Speed']
pokemod2.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  Speed  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49     45
# 1  2                Ivysaur  Grass  Poison    405  60      62       63     60
# 2  3               Venusaur  Grass  Poison    525  80      82       83     80
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123     80
# 4  4             Charmander   Fire     NaN    309  39      52       43     65
#
#    Legendary  isPokemon  Offense
# 0        NaN       True       94
# 1        NaN       True      122
# 2        NaN       True      162
# 3        NaN       True      180
# 4        NaN       True      117

# %%
pokemod2['TrueDef'] = pokemod2.iloc[:,7:9].sum(axis=1)
pokemod2.head()

# %%
pokecols = pokemod.columns.to_list()
print(pokecols)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']

# %%
pokecols = pokecols[:8] + [pokecols[10]] + pokecols[8:10] + pokecols[11:]
print(pokecols)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Speed', 'Sp. Atk', 'Sp. Def', 'Generation', 'Legendary']

# %%
pokemod = pokemod[pokecols]
pokemod.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  Speed  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49     45
# 1  2                Ivysaur  Grass  Poison    405  60      62       63     60
# 2  3               Venusaur  Grass  Poison    525  80      82       83     80
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123     80
# 4  4             Charmander   Fire     NaN    309  39      52       43     65
#
#    Sp. Atk  Sp. Def  Generation  Legendary
# 0       65       65           1      False
# 1       80       80           1      False
# 2      100      100           1      False
# 3      122      120           1      False
# 4       60       50           1      False

# %% [markdown]
# ## Filtering Data
#
# ---
#
# ### Displaying data values based on conditions
#
#
# Let's try to find weird combination of pokemon types and see which pokemons have the highest of each attribute
#
#
#
# Pandas documentation:
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html

# %%
# code here

pokemod.loc[pokemod['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    318   45      49       49
# 1      2                Ivysaur  Grass    Poison    405   60      62       63
# 2      3               Venusaur  Grass    Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    625   80     100      123
# 48    43                 Oddish  Grass    Poison    320   45      50       55
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN    313   56      61       65
# 719  651              Quilladin  Grass       NaN    405   61      78       95
# 720  652             Chesnaught  Grass  Fighting    530   88     107      122
# 740  672                 Skiddo  Grass       NaN    350   66      65       48
# 741  673                 Gogoat  Grass       NaN    531  123     100       62
#
#      Speed  Sp. Atk  Sp. Def  Generation  Legendary
# 0       45       65       65           1      False
# 1       60       80       80           1      False
# 2       80      100      100           1      False
# 3       80      122      120           1      False
# 48      30       75       65           1      False
# ..     ...      ...      ...         ...        ...
# 718     38       48       45           6      False
# 719     57       56       58           6      False
# 720     64       74       75           6      False
# 740     52       62       57           6      False
# 741     68       97       81           6      False
#
# [70 rows x 13 columns]

# %%
pokemod.loc[(pokemod['Type 1'] == 'Grass') & (pokemod['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 48    43                 Oddish  Grass  Poison    320   45      50       55
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 75    69             Bellsprout  Grass  Poison    300   50      75       35
# 76    70             Weepinbell  Grass  Poison    390   65      90       50
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 344  315                Roselia  Grass  Poison    400   50      60       45
# 451  406                  Budew  Grass  Poison    280   40      30       35
# 452  407               Roserade  Grass  Poison    515   60      70       65
# 651  590                Foongus  Grass  Poison    294   69      55       45
# 652  591              Amoonguss  Grass  Poison    464  114      85       70
#
#      Speed  Sp. Atk  Sp. Def  Generation  Legendary
# 0       45       65       65           1      False
# 1       60       80       80           1      False
# 2       80      100      100           1      False
# 3       80      122      120           1      False
# 48      30       75       65           1      False
# 49      40       85       75           1      False
# 50      50      110       90           1      False
# 75      40       70       30           1      False
# 76      55       85       45           1      False
# 77      70      100       70           1      False
# 344     65      100       80           3      False
# 451     55       50       70           4      False
# 452     90      125      105           4      False
# 651     15       55       55           5      False
# 652     30       85       80           5      False

# %%
pokemod.loc[(pokemod['Type 1'] == 'Grass') | (pokemod['Type 1'] == 'Poison')]
# Out:
#        #                   Name  Type 1    Type 2  Total   HP  Attack  \
# 0      1              Bulbasaur   Grass    Poison    318   45      49
# 1      2                Ivysaur   Grass    Poison    405   60      62
# 2      3               Venusaur   Grass    Poison    525   80      82
# 3      3  VenusaurMega Venusaur   Grass    Poison    625   80     100
# 28    23                  Ekans  Poison       NaN    288   35      60
# ..   ...                    ...     ...       ...    ...  ...     ...
# 720  652             Chesnaught   Grass  Fighting    530   88     107
# 740  672                 Skiddo   Grass       NaN    350   66      65
# 741  673                 Gogoat   Grass       NaN    531  123     100
# 760  690                 Skrelp  Poison     Water    320   50      60
# 761  691               Dragalge  Poison    Dragon    494   65      75
#
#      Defense  Speed  Sp. Atk  Sp. Def  Generation  Legendary
# 0         49     45       65       65           1      False
# 1         63     60       80       80           1      False
# 2         83     80      100      100           1      False
# 3        123     80      122      120           1      False
# 28        44     55       40       54           1      False
# ..       ...    ...      ...      ...         ...        ...
# 720      122     64       74       75           6      False
# 740       48     52       62       57           6      False
# 741       62     68       97       81           6      False
# 760       60     30       60       60           6      False
# 761       90     44       97      123           6      False
#
# [98 rows x 13 columns]

# %%
pokemod.loc[pokemod['Attack'] >= 170]
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# 494  445    GarchompMega Garchomp   Dragon    Ground    700  108     170
# 711  646       KyuremBlack Kyurem   Dragon       Ice    700  125     170
#
#      Defense  Speed  Sp. Atk  Sp. Def  Generation  Legendary
# 163      100    130      154      100           1       True
# 232      115     75       40      105           2      False
# 424      160     90      150       90           3       True
# 426      100    115      180      100           3       True
# 429       20    150      180       20           3       True
# 494      115     92      120       95           4      False
# 711      100     95      120       90           5       True

# %%
pokemod.loc[(pokemod['Attack'] >= 170) & (pokemod['Legendary'] == False)]
# Out:
#        #                     Name  Type 1    Type 2  Total   HP  Attack  \
# 232  214  HeracrossMega Heracross     Bug  Fighting    600   80     185
# 494  445    GarchompMega Garchomp  Dragon    Ground    700  108     170
#
#      Defense  Speed  Sp. Atk  Sp. Def  Generation  Legendary
# 232      115     75       40      105           2      False
# 494      115     92      120       95           4      False

# %% [markdown]
# ## Conditional Changes
#
# ---
#
# ### Replacing values based on conditions/filters
#
#
# Let's change some values based on pokemon types
#
#
#
# Pandas documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html

# %% [markdown]
# #### Note/Cheat Sheet on Common Pandas Operators:
#
# ```
# AND can be reprented as &
# OR can be reprented as |
# NOT can be reprented as ~
# ```

# %%
# code here

pokemod.loc[pokemod['Total'] >= 500, 'Overpowered'] = True
pokemod.loc[pokemod['Total'] < 500, 'Overpowered'] = False
pokemod
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Speed  Sp. Atk  Sp. Def  Generation  Legendary Overpowered
# 0       45       65       65           1      False       False
# 1       60       80       80           1      False       False
# 2       80      100      100           1      False        True
# 3       80      122      120           1      False        True
# 4       65       60       50           1      False       False
# ..     ...      ...      ...         ...        ...         ...
# 795     50      100      150           6       True        True
# 796    110      160      110           6       True        True
# 797     70      150      130           6       True        True
# 798     80      170      130           6       True        True
# 799     70      130       90           6       True        True
#
# [800 rows x 14 columns]

# %%
pokemod2.loc[pokemod['Type 1'] == 'Bug', 'Type 1'] = 'Insect'
pokemod2.loc[pokemod['Type 1'] == 'Bug']
# Out:
#        #        Name  Type 1  Type 2  Total  HP  Attack  Defense  Speed  \
# 13    10    Caterpie  Insect     NaN    195  45      30       35     45
# 14    11     Metapod  Insect     NaN    205  50      20       55     30
# 15    12  Butterfree  Insect  Flying    395  60      45       50     70
# 16    13      Weedle  Insect  Poison    195  40      35       30     50
# 17    14      Kakuna  Insect  Poison    205  45      25       50     35
# ..   ...         ...     ...     ...    ...  ..     ...      ...    ...
# 698  637   Volcarona  Insect    Fire    550  85      60       65    100
# 717  649    Genesect  Insect   Steel    600  71     120       95     99
# 732  664  Scatterbug  Insect     NaN    200  38      35       40     35
# 733  665      Spewpa  Insect     NaN    213  45      22       60     29
# 734  666    Vivillon  Insect  Flying    411  80      52       50     89
#
#      Legendary  isPokemon  Offense  TrueDef
# 13         NaN       True       75       80
# 14         NaN       True       50       85
# 15         NaN       True      115      120
# 16         NaN       True       85       80
# 17         NaN       True       60       85
# ..         ...        ...      ...      ...
# 698        NaN       True      160      165
# 717        NaN       True      219      194
# 732        NaN       True       70       75
# 733        NaN       True       51       89
# 734        NaN       True      141      139
#
# [69 rows x 13 columns]

# %% [markdown]
# ## Aggregate Statistics
#
# ---
#
# ### Using the groupby function with numpy functions
#
#
# Let's see what type of pokemon has the highest average and median of each atttribute
#
#
#
# Pandas documentation: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html

# %%
# code here

pokemod.groupby(['Type 1']).mean()
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
#
#                Speed    Sp. Atk    Sp. Def  Generation  Legendary
# Type 1
# Bug        61.681159  53.869565  64.797101    3.217391   0.000000
# Dark       76.161290  74.645161  69.516129    4.032258   0.064516
# Dragon     83.031250  96.843750  88.843750    3.875000   0.375000
# Electric   84.500000  90.022727  73.704545    3.272727   0.090909
# Fairy      48.588235  78.529412  84.705882    4.117647   0.058824
# Fighting   66.074074  53.111111  64.703704    3.370370   0.000000
# Fire       74.442308  88.980769  72.211538    3.211538   0.096154
# Flying    102.500000  94.250000  72.500000    5.500000   0.500000
# Ghost      64.343750  79.343750  76.468750    4.187500   0.062500
# Grass      61.928571  77.500000  70.428571    3.357143   0.042857
# Ground     63.906250  56.468750  62.750000    3.156250   0.125000
# Ice        63.458333  77.541667  76.291667    3.541667   0.083333
# Normal     71.551020  55.816327  63.724490    3.051020   0.020408
# Poison     63.571429  60.428571  64.392857    2.535714   0.000000
# Psychic    81.491228  98.403509  86.280702    3.385965   0.245614
# Rock       55.909091  63.340909  75.477273    3.454545   0.090909
# Steel      55.259259  67.518519  80.629630    3.851852   0.148148
# Water      65.964286  74.812500  70.517857    2.857143   0.035714

# %%
pokemod.groupby(['Type 1']).median()
# Out:
#               #  Total    HP  Attack  Defense  Speed  Sp. Atk  Sp. Def  \
# Type 1
# Bug       291.0  395.0  60.0    65.0     60.0   60.0     50.0     60.0
# Dark      509.0  465.0  65.0    88.0     70.0   70.0     65.0     65.0
# Dragon    443.5  600.0  80.0   113.5     90.0   90.0    105.0     90.0
# Electric  403.5  477.5  60.0    65.0     65.0   88.0     95.0     79.5
# Fairy     669.0  405.0  78.0    52.0     66.0   45.0     75.0     79.0
# Fighting  308.0  455.0  70.0   100.0     70.0   60.0     40.0     63.0
# Fire      289.5  482.0  70.0    84.5     64.0   78.5     85.0     67.5
# Flying    677.5  557.5  79.0    85.0     75.0  116.0    103.5     80.0
# Ghost     487.0  464.5  59.5    66.0     72.5   60.5     65.0     75.0
# Grass     372.0  430.0  65.5    70.0     66.0   58.5     75.0     66.0
# Ground    363.5  440.0  75.0    85.0     84.5   65.0     47.5     62.5
# Ice       371.5  467.5  70.0    67.0     75.0   62.0     77.5     70.0
# Normal    296.5  415.0  70.0    70.5     60.0   71.0     50.0     60.5
# Poison    139.5  401.5  67.5    74.0     67.0   62.5     60.0     60.5
# Psychic   386.0  485.0  68.0    57.0     65.0   80.0     95.0     90.0
# Rock      362.5  467.5  68.5    95.0    100.0   50.0     60.0     70.0
# Steel     379.0  500.0  60.0    89.0    120.0   50.0     55.0     80.0
# Water     275.0  455.0  70.0    72.0     70.0   65.0     70.0     65.0
#
#           Generation  Legendary
# Type 1
# Bug              3.0        0.0
# Dark             5.0        0.0
# Dragon           4.0        0.0
# Electric         4.0        0.0
# Fairy            6.0        0.0
# Fighting         3.0        0.0
# Fire             3.0        0.0
# Flying           5.5        0.5
# Ghost            4.0        0.0
# Grass            3.5        0.0
# Ground           3.0        0.0
# Ice              3.0        0.0
# Normal           3.0        0.0
# Poison           1.5        0.0
# Psychic          3.0        0.0
# Rock             3.0        0.0
# Steel            3.0        0.0
# Water            3.0        0.0

# %%
pokemod.groupby(['Type 1']).mean().sort_values('Attack', ascending=False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
#
#                Speed    Sp. Atk    Sp. Def  Generation  Legendary
# Type 1
# Dragon     83.031250  96.843750  88.843750    3.875000   0.375000
# Fighting   66.074074  53.111111  64.703704    3.370370   0.000000
# Ground     63.906250  56.468750  62.750000    3.156250   0.125000
# Rock       55.909091  63.340909  75.477273    3.454545   0.090909
# Steel      55.259259  67.518519  80.629630    3.851852   0.148148
# Dark       76.161290  74.645161  69.516129    4.032258   0.064516
# Fire       74.442308  88.980769  72.211538    3.211538   0.096154
# Flying    102.500000  94.250000  72.500000    5.500000   0.500000
# Poison     63.571429  60.428571  64.392857    2.535714   0.000000
# Water      65.964286  74.812500  70.517857    2.857143   0.035714
# Ghost      64.343750  79.343750  76.468750    4.187500   0.062500
# Normal     71.551020  55.816327  63.724490    3.051020   0.020408
# Grass      61.928571  77.500000  70.428571    3.357143   0.042857
# Ice        63.458333  77.541667  76.291667    3.541667   0.083333
# Psychic    81.491228  98.403509  86.280702    3.385965   0.245614
# Bug        61.681159  53.869565  64.797101    3.217391   0.000000
# Electric   84.500000  90.022727  73.704545    3.272727   0.090909
# Fairy      48.588235  78.529412  84.705882    4.117647   0.058824

# %% [markdown]
# ## Exporting Our Dataframe
#
# ---
#
# ### Saving our dataframe into a csv or other type of file
#
#
# Let's save our dataframe into a seperate csv file
#
# Pandas documentation:
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_csv.html
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_json.html

# %%
# code here
pokemod.to_csv('rearrangedpokemon.csv')
pokemod2.to_json('clownedpokemon.json')

# %% [markdown]
# ## Using a real world dataset:
#
# ---
# https://www.kaggle.com/jolasa/bay-area-bike-sharing-trips

# %%
# Importing the new data

bike_df = pd.read_csv('2019 - 01.csv')

# %% [markdown]
# ### Lets rearrange the dataset according to our task:
#
# " Predict the trip duration based on the start_station_name, user_type, member_birth year, and member_gender"

# %%
# Rearrange the data

cols = bike_df.columns.tolist()
print(cols)

# %%
cols = col[0] + col[2:] + col[1]
print(cols)

# %%
bike_df = bike_df[cols]
bike_df.head()

# %%
bike_df.drop(colums=['start_station_id','end_station_id','bike_id'],inplace=True)

# %% [markdown]
# ### Lets use what we learned to get some general info from this dataset:
# - Unique values
# - Duplicates
# - Aggregate statistics
# - Null/NaN values

# %%
# Combing through the data

pd.unique(bike_df[user_type])

# %%
pd.unique(bike_df[member_gender])

# %%
pd.unique(bike_df[month])

# %%
bike_df.isna().sum()

# %%
bike_df.duplicated(subset=['start_station_name'])

# %%
bike_df.groupby(['member_gender'])mean()
